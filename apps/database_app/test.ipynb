# %%
import sqlite3
import pandas as pd

# %%
dfs = []
with sqlite3.connect("../../database_vol/sensor_readings.db") as conn:
    cursor = conn.cursor()
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")

    for table_name in cursor.fetchall():
        dfs.append(pd.read_sql_query(f"SELECT * FROM {table_name[0]}", conn))

    new_col_names = [name.lower().replace(" ", "_") for name in dfs[0].columns]
    for i, df in enumerate(dfs):
        if df.shape[1] > 11:
            dfs[i].drop(inplace=True, columns=df.columns[11:])
        dfs[i].columns = new_col_names

with sqlite3.connect("../../database_vol/sensor_readings.db") as conn:
    cursor = conn.cursor()
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    
    for df, table_name in zip(dfs, cursor.fetchall()):
        try:
            df.to_sql(table_name[0], conn, if_exists='replace', index=False)
            print(f"Table {table_name} replaced successfully.")
        except ValueError as e:
            print(f"Error: {e}")
# Out:
# Table ('iot_pond_0',) replaced successfully.
# Table ('iot_pond_1',) replaced successfully.
# Table ('iot_pond_2',) replaced successfully.
# Table ('iot_pond_3',) replaced successfully.
# Table ('iot_pond_4',) replaced successfully.
# Table ('iot_pond_5',) replaced successfully.
# Table ('iot_pond_6',) replaced successfully.
# Table ('iot_pond_7',) replaced successfully.
# Table ('iot_pond_8',) replaced successfully.
# Table ('iot_pond_9',) replaced successfully.
# Table ('iot_pond_10',) replaced successfully.

# %%
dfs = []
with sqlite3.connect("../../database_vol/sensor_readings.db") as conn:
    cursor = conn.cursor()
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")

    for table_name in cursor.fetchall():
        dfs.append(pd.read_sql_query(f"SELECT * FROM {table_name[0]}", conn))
